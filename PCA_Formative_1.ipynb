# %% [markdown]
# # Formative Assignment: Advanced Linear Algebra (PCA)
# This notebook will guide you through the implementation of Principal Component Analysis (PCA). Fill in the missing code and provide the required answers in the appropriate sections. You will work with a dataset that is Africanized .
#
# Make sure to display outputs for each code cell when submitting.

# %% [markdown]
# ### Step 1: Load and Standardize the Data
# Before applying PCA, we must standardize the dataset. Standardization ensures that all features have a mean of 0 and a standard deviation of 1, which is essential for PCA.
# Fill in the code to standardize the dataset.
#
# STRICTLY - Write code that implements standardization based on the image below
#
# <img src='data:image/jpeg;base64,...'/>

# %%
# Step 1: Load and Standardize the data (use of numpy only allowed)
# Step 1: Load and Standardize the Data (NumPy only)

import pandas as pd
import numpy as np

# Load data
data = pd.read_csv("AfricanData.csv")

# Keep only numeric columns (drop non-numeric like Province, Station, Category, etc.)
numeric_data = data.select_dtypes(include=[np.number])

# Handle missing values by replacing NaN with column mean
numeric_data = numeric_data.fillna(numeric_data.mean())

# Convert to NumPy array
X = numeric_data.values

# Standardization: (X - mean) / standard deviation
mean = np.mean(X, axis=0)
std = np.std(X, axis=0)

standardized_data = (X - mean) / std

# Display first 5 rows
standardized_data[:5]
  # Display the first few rows of standardized data
# Out:
# array([[-1.00000000e+00, -3.22549979e-01,  2.38572343e-01,
#         -1.17660303e+00, -1.97968418e-01,  6.88289361e-03,
#          1.60248268e-02, -4.98163456e-01,  4.85331869e-01,
#         -8.55284339e-01, -1.16647737e+00,  1.94544934e-01],
#        [ 1.00000000e+00, -3.57447757e-01,  3.08059433e-01,
#         -7.93991288e-01, -1.07797871e-01,  2.03045361e-01,
#          9.14357763e-02, -5.19294461e-01,  5.45976057e-01,
#         -8.44471642e-01, -1.04371028e+00,  2.34722692e-01],
#        [-1.00000000e+00,  8.02285365e-02, -6.69392302e-01,
#         -4.05306342e-01, -6.61702656e-01, -1.03931693e+00,
#         -2.32171461e+00, -3.55529168e-01,  1.10604297e+00,
#          7.44994829e-01, -1.44089791e+00, -1.26877131e-01],
#        [ 1.00000000e+00, -1.18252573e-01, -6.18435102e-01,
#         -9.55730254e-02,  1.43013452e-15, -9.08541956e-01,
#         -2.15203997e+00, -3.76660174e-01,  1.13458141e+00,
#          7.55807526e-01, -1.32535242e+00, -6.34385654e-03],
# ...

# %% [markdown]
# ### Step 3: Calculate the Covariance Matrix
# The covariance matrix helps us understand how the features are related to each other. It is a key component in PCA.

# %%
# Step 3: Calculate the Covariance Matrix
# Covariance matrix
cov_matrix = np.cov(standardized_data.T)  # transpose is important

# Display covariance matrix
print(cov_matrix)
# Out:
# [[ 1.05263158e+00 -2.92728068e-02  2.04804055e-02  1.19781718e-01
#    7.14370533e-02  1.37295615e-01  4.66357188e-02 -2.94721919e-02
#    1.29549504e-02 -1.16865582e-17  5.37718640e-02  4.61506288e-02]
#  [-2.92728068e-02  1.05263158e+00  7.35553803e-01  8.51567332e-01
#    9.26052701e-01  5.06813702e-01  4.92227382e-02  9.92633677e-01
#   -7.85554097e-01  6.04676883e-01  7.31206328e-01  9.91598954e-01]
#  [ 2.04804055e-02  7.35553803e-01  1.05263158e+00  8.85857146e-01
#    8.92096898e-01  1.96110082e-01  4.55136069e-01  5.33518464e-01
#   -8.31708624e-01  5.42878168e-01  7.66738704e-01  6.26873020e-01]
#  [ 1.19781718e-01  8.51567332e-01  8.85857146e-01  1.05263158e+00
#    9.12925961e-01  2.88686244e-01  3.65133105e-01  7.03036885e-01
#   -8.18278562e-01  5.96637682e-01  8.46450768e-01  7.07022056e-01]
#  [ 7.14370533e-02  9.26052701e-01  8.92096898e-01  9.12925961e-01
#    1.05263158e+00  4.19342834e-01  2.90883818e-01  8.06578597e-01
# ...

# %% [markdown]
# ### Step 4: Perform Eigendecomposition
# Eigendecomposition of the covariance matrix will give us the eigenvalues and eigenvectors, which are essential for PCA.
# Fill in the code to compute the eigenvalues and eigenvectors of the covariance matrix.

# %%
# Step 4: Perform Eigendecomposition
# Perform eigendecomposition on covariance matrix
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

# Display results
print("Eigenvalues:\n", eigenvalues)
print("\nEigenvectors:\n", eigenvectors)
# Out:
# Eigenvalues:
#  [7.48834165e+00 1.57031373e+00 1.14351288e+00 1.00085261e+00
#  8.02854094e-01 3.22777501e-01 1.52367039e-01 1.05072677e-01
#  2.84452736e-02 1.12180121e-02 3.95654074e-03 1.86694051e-03]
#
# Eigenvectors:
#  [[ 0.01748111 -0.08458477  0.71402216 -0.67284256  0.02674924  0.04985178
#   -0.08540672 -0.03617707  0.10622951 -0.07180144  0.03818183 -0.01712463]
#  [ 0.34839788  0.23457459 -0.09335316 -0.05531779 -0.17383102 -0.07423052
#    0.16615444 -0.1772662   0.5741494   0.1523572   0.43172763  0.42167737]
#  [ 0.31082426 -0.27793824 -0.20505339 -0.16827037  0.04025222 -0.54076324
#   -0.41247192  0.26267963  0.22796708  0.28525547 -0.10744052 -0.27877386]
#  [ 0.33434573 -0.15966955 -0.11030672 -0.23523823 -0.03104674 -0.06088329
#    0.74676241  0.41173982 -0.22089043 -0.05736774  0.03392615 -0.10062254]
#  [ 0.35672237 -0.02973024 -0.08339704 -0.12971256  0.11982794 -0.13534403
#   -0.02306505 -0.67172683 -0.53489165  0.16423748  0.2018711  -0.09911717]
# ...

# %% [markdown]
# ### Step 5: Sort Principal Components
# Sort the eigenvectors based on their corresponding eigenvalues in descending order. The higher the eigenvalue, the more important the eigenvector.
# Complete the code to sort the eigenvectors and print the sorted components.
#
# <a url ='https://www.youtube.com/watch?v=vaF-1xUEXsA&t=17s'>How Is Explained Variance Used In PCA?'<a/>

# %%
# Step 5: Sort eigenvalues in descending order
sorted_indices = np.argsort(eigenvalues)[::-1]  # indices of eigenvalues from largest to smallest

# Sort eigenvectors accordingly
sorted_eigenvectors = eigenvectors[:, sorted_indices]

# Sort eigenvalues too (optional, for explained variance)
sorted_eigenvalues = eigenvalues[sorted_indices]

# Display sorted eigenvectors
print("Sorted Eigenvectors:\n", sorted_eigenvectors)
print("\nSorted Eigenvalues:\n", sorted_eigenvalues)
# Out:
# Sorted Eigenvectors:
#  [[ 0.01748111 -0.08458477  0.71402216 -0.67284256  0.02674924  0.04985178
#   -0.08540672 -0.03617707  0.10622951 -0.07180144  0.03818183 -0.01712463]
#  [ 0.34839788  0.23457459 -0.09335316 -0.05531779 -0.17383102 -0.07423052
#    0.16615444 -0.1772662   0.5741494   0.1523572   0.43172763  0.42167737]
#  [ 0.31082426 -0.27793824 -0.20505339 -0.16827037  0.04025222 -0.54076324
#   -0.41247192  0.26267963  0.22796708  0.28525547 -0.10744052 -0.27877386]
#  [ 0.33434573 -0.15966955 -0.11030672 -0.23523823 -0.03104674 -0.06088329
#    0.74676241  0.41173982 -0.22089043 -0.05736774  0.03392615 -0.10062254]
#  [ 0.35672237 -0.02973024 -0.08339704 -0.12971256  0.11982794 -0.13534403
#   -0.02306505 -0.67172683 -0.53489165  0.16423748  0.2018711  -0.09911717]
#  [ 0.20561049  0.19909344  0.58940265  0.50717026  0.07927868 -0.13227702
#    0.06239361  0.21206003 -0.15470313  0.46490547  0.02691345  0.00545335]
# ...

# %% [markdown]
# ### Step 6: Project Data onto Principal Components
# Now that we’ve selected the number of components, we will project the original data onto the chosen principal components.
# Fill in the code to perform the projection.

# %%
# Step 6: Project Data onto Principal Components


# Decide number of principal components to keep
num_components = 2  # change this number based on explained variance

# Select the top 'num_components' eigenvectors
top_eigenvectors = sorted_eigenvectors[:, :num_components]

# Project standardized data onto these principal components
reduced_data = standardized_data @ top_eigenvectors

# Display first 5 rows of reduced data
print(reduced_data[:5])
# Out:
# [[-1.36304535  0.32160209]
#  [-1.08391919  0.03355583]
#  [-1.85302714  2.23772858]
#  [-1.42515002  1.85952814]
#  [ 5.37967088  2.3773276 ]]

# %% [markdown]
# ### Step 7: Output the Reduced Data
# Finally, display the reduced data obtained by projecting the original dataset onto the selected principal components.

# %%
# Step 7: Output the Reduced Data
print(f'Reduced Data Shape: {reduced_data.shape}')  # Display reduced data shape
reduced_data[:5]  # Display the first few rows of reduced data
# Out:
# Reduced Data Shape: (20, 2)
# array([[-1.36304535,  0.32160209],
#        [-1.08391919,  0.03355583],
#        [-1.85302714,  2.23772858],
#        [-1.42515002,  1.85952814],
#        [ 5.37967088,  2.3773276 ]])

# %% [markdown]
# ### Step 8: Visualize Before and After PCA
# Now, let's plot the original data and the data after PCA to compare the reduction in dimensions visually.

# %%
## Step 8: Visualize Before and After PCA
import matplotlib.pyplot as plt

# Step 8: Visualize Before and After PCA

# Plot original data (first two features for simplicity)
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.scatter(standardized_data[:, 0], standardized_data[:, 1], c='blue', alpha=0.6)
plt.title('Original Data (first 2 features)')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')

# Plot reduced data after PCA (first two principal components)
plt.subplot(1, 2, 2)
plt.scatter(reduced_data[:, 0], reduced_data[:, 1], c='red', alpha=0.6)
plt.title('Reduced Data after PCA')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')

plt.tight_layout()
plt.show()
